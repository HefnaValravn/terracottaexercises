# %% [markdown]
# # TMDB movies

# %% [markdown]
# Load all the necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as md

# %% [markdown]
# Load the dataset into a DataFrame and inspect the first rows of the DataFrame.

# %%
data = pd.read_csv('TMDB-movies-small.csv', encoding='utf-8')
data.head(5)
# Out:
#    Unnamed: 0  id               title  vote_average  vote_count    status  \
# 0          11  16  Dancer in the Dark         7.868        1697  Released
# 1          26  55       Amores Perros         7.600        2475  Released
# 2          31  64         Talk to Her         7.579        1233  Released
# 3          32  65              8 Mile         7.134        6958  Released
# 4          38  71        Billy Elliot         7.600        3691  Released
#
#   release_date      revenue  runtime      budget  ...                genres  \
# 0   2000-09-01   40061153.0      140  12500000.0  ...          Drama, Crime
# 1   2000-06-16   20908467.0      154   2000000.0  ...       Drama, Thriller
# 2   2002-03-15   64803131.0      112         0.0  ...        Drama, Romance
# 3   2002-11-08  242875078.0      111  41000000.0  ...          Drama, Music
# 4   2000-09-28  109280263.0      110   5000000.0  ...  Drama, Comedy, Music
#
#                                 production_companies  \
# 0  Lantia Cinema & Audiovisivi, Fine Line Feature...
# 1                         Altavista Films, Zeta Film
# 2    Vía Digital, Good Machine, El Deseo, Atresmedia
# 3          Mikona Productions, Imagine Entertainment
# 4  StudioCanal, BBC Film, Tiger Aspect, Arts Coun...
#
#                                 production_countries spoken_languages  \
# 0  Argentina, Denmark, Finland, France, Germany, ...          English
# 1                                             Mexico          Español
# 2                                              Spain          Español
# 3                  Germany, United States of America          English
# 4   France, United Kingdom, United States of America          English
#
#                                                 cast  \
# 0  Bobo Eriksson, Caroline Sascha Cogez, Bo Weste...
# 1  Gerardo Campbell, Rosa María Bianchi, Ricardo ...
# 2  Carlos García Cambero, Leonor Watling, Pina Ba...
# 3  Malik Barnhardt, Mike Bell, Allen Adams, Abdul...
# 4  Lee Williams, Colin MacLachlan, Neil North, Pa...
#
#                       director director_of_photography               writers  \
# 0               Lars von Trier            Robby Müller  Sjón, Lars von Trier
# 1  Alejandro González Iñárritu          Rodrigo Prieto     Guillermo Arriaga
# 2              Pedro Almodóvar    Javier Aguirresarobe       Pedro Almodóvar
# 3                Curtis Hanson          Rodrigo Prieto          Scott Silver
# 4               Stephen Daldry            Brian Tufano              Lee Hall
#
#                                            producers  \
# 0  Leo Pescarolo, Peter Aalbæk Jensen, Vibeke Win...
# 1  Martha Sosa Elizondo, Francisco González Compe...
# 2                    Michel Ruben, Agustín Almodóvar
# 3  Jimmy Iovine, Jim Whitaker, Brian Grazer, Greg...
# 4  Jonathan Finn, Natascha Wharton, Tessa Ross, D...
#
#                     music_composer
# 0                            Björk
# 1              Gustavo Santaolalla
# 2  Alberto Iglesias, Vicente Amigo
# 3                              NaN
# 4                  Stephen Warbeck
#
# [5 rows x 26 columns]

# %% [markdown]
# Create a new DataFrame with all the movies released in 2000. Tip: Format the release dates as pandas datetime objects. Inspect the amount of rows in the new DataFrame.

# %%
data['release_date'] = pd.to_datetime(data['release_date'], format = '%Y-%m-%d')
sparta = data[data['release_date'].dt.year == 2000]
sparta['release_date'].count()
# Out:
# 2850

# %% [markdown]
# Create a new DataFrame df_topmovies which only incorporates the rows with the movies of the year 2000 who get an average score of at least 9. Compare the total rows of the original dataframe with df_topmovies. (Tip: use shape)

# %%
gudsparta = sparta[sparta['vote_average'] >= 9]
gudsparta

print(gudsparta['title'].count())
print(sparta['title'].count())
# Out:
# 185
# 2850

# %% [markdown]
# Replace all NaN's with 0.

# %%
sparta.fillna(0)
gudsparta.fillna(0, inplace=True)

gudsparta
# Out:
# /tmp/ipykernel_15899/1114331439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gudsparta.fillna(0, inplace=True)
#       Unnamed: 0       id                              title  vote_average  \
# 1313       17027    28002                      Lazarus Lives          10.0
# 1388       18982    30553    Emperor: Emperial Live Ceremony          10.0
# 1659       23609    37664             Eurythmics - Peacetour           9.0
# 2380       38178    55698         Escape to Grizzly Mountain          10.0
# 2499       40712    59077    Une Femme Taxi à Sidi Bel Abbès          10.0
# ...          ...      ...                                ...           ...
# 9343      817045  1150924   Morten og peter - ikke helt gak!          10.0
# 9347      820190  1154916  Chikan torakku: Injo norippanashi           9.5
# 9352      828664  1166244                      Mai dire 2000          10.0
# 9372      860724  1206012                              Sissy           9.0
# 9390      896385  1248655                         Dog's Home           9.0
#
#       vote_count    status release_date  revenue  runtime  budget  ...  \
# 1313           1  Released   2000-06-01      0.0       30     0.0  ...
# 1388           1  Released   2000-05-15      0.0       61     0.0  ...
# 1659           2  Released   2000-07-20      0.0       96     0.0  ...
# 2380           1  Released   2000-03-14      0.0       95     0.0  ...
# 2499           1  Released   2000-07-03      0.0       52     0.0  ...
# ...          ...       ...          ...      ...      ...     ...  ...
# 9343           1  Released   2000-01-13      0.0        0     0.0  ...
# 9347           1  Released   2000-09-05      0.0       60     0.0  ...
# 9352           1  Released   2000-12-27      0.0       46     0.0  ...
# 9372           1  Released   2000-01-01      0.0       27     0.0  ...
# 9390           1  Released   2000-10-01      0.0       85     0.0  ...
#
#                               genres  \
# 1313               Animation, Family
# 1388                           Music
# 1659                           Music
# 2380  Fantasy, Drama, Family, Comedy
# 2499                     Documentary
# ...                              ...
# 9343                     Documentary
# 9347                 Romance, Comedy
# 9352                          Comedy
# 9372                     Documentary
# 9390                           Drama
#
#                                    production_companies  \
# 1313  Rich Animation Studios, NEST Family Entertainm...
# 1388                                Wildcat Productions
# 1659                                                BMG
# 2380                           MGM Family Entertainment
# 2499    Les Films de la Passerelle, Machaho Productions
# ...                                                 ...
# 9343                                               TV 2
# 9347                                                  0
# 9352                                                  0
# 9372   Reel Images, Australian Broadcasting Corporation
# 9390                             Filmmaker Features LLC
#
#           production_countries spoken_languages  \
# 1313  United States of America          English
# 1388    Norway, United Kingdom          English
# 1659            United Kingdom          English
# 2380  United States of America                0
# 2499          Algeria, Belgium          العربية
# ...                        ...              ...
# 9343                   Denmark            Dansk
# 9347                     Japan              日本語
# 9352                     Italy         Italiano
# 9372                 Australia                0
# 9390                         0   български език
#
#                                                    cast            director  \
# 1313  Karen Kondazian, Ann Marie Lee, Andrew Craig, ...        Richard Rich
# 1388  Charmand Grimloch, Jan Erik Tiwaz, Vegard Sver...                   0
# 1659                         Annie Lennox, Dave Stewart       David Barnard
# 2380  Charlotte Dodds, Miko Hughes, Dan Haggerty, Cy...  Anthony Dalesandro
# 2499                                                  0    Belkacem Hadjadj
# ...                                                 ...                 ...
# 9343                                                  0                   0
# 9347   Motoko Sasaki, Masanori Machida, Sheena Nagamori    Kazuyoshi Sekine
# 9352   Giorgio Gherarducci, Carlo Taranto, Marco Santin   Andrea Fantonelli
# 9372  Anna Mae, Charles Colbung, John Collard, John ...      Debbie Gittens
# 9390  Georgi Kurkelanov, Nikolai Binev, Dossio Dosse...  Stephan Komandarev
#
#      director_of_photography  \
# 1313                       0
# 1388                       0
# 1659                       0
# 2380            Steve Adcock
# 2499                       0
# ...                      ...
# 9343                       0
# 9347                       0
# 9352                       0
# 9372      Leighton De Barros
# 9390       Vladimir Mihaylov
#
#                                                 writers  \
# 1313                                       Brian Nissen
# 1388                                                  0
# 1659                                                  0
# 2380  Eric Parkinson, Beau Bauman, Lisa Dalesandro, ...
# 2499                                   Belkacem Hadjadj
# ...                                                 ...
# 9343                                                  0
# 9347                                                  0
# 9352                                                  0
# 9372                                     Debbie Gittens
# 9390                                       Yurii Dachev
#
#                                               producers music_composer
# 1313      Jared F. Brown, Richard Rich, Seldon O. Young              0
# 1388                                                  0              0
# 1659                          Geoff Foulkes, Mark Harry              0
# 2380  Herb Linsey, Tony Cataldo, Menahem Golan, Geor...              0
# 2499                                  Christine Pireaux              0
# ...                                                 ...            ...
# 9343                                                  0              0
# 9347                                                  0              0
# 9352                                                  0              0
# 9372                         David Jowsey, Brian Beaton              0
# 9390                                Christopher Bojilov              0
#
# [185 rows x 26 columns]

# %% [markdown]
# Plot the data using a graph with on the x-axis the release dates and on the y-axis the runtime of the film.
# * Use appropriate labels and titles
# * Change the ticks and tick labels so every month has a tick and as label the abbreviation of the month (Jan, Feb, March etc.)
# * Change the color of the graph
# * Show a grid
# * Show the legend

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
gudsparta.plot(x='release_date', xlabel='Release Date', y='runtime', ylabel='Runtime', title='Runtime vs Release Date', kind='scatter', figsize=(10, 5))
months = md.MonthLocator()  # Set the locator to months
months_fmt = md.DateFormatter('%b')
plt.gca().xaxis.set_major_locator(months)
plt.gca().xaxis.set_major_formatter(months_fmt)

plt.grid(True)
plt.show()
